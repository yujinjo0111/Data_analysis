# %%
import pandas as pd
CCTV_Seoul= pd.read_csv('01.CCTV_in_Seoul.csv', encoding = "utf-8")
CCTV_Seoul.head()
# Out:
#     구분    총 계 2015년 이전\n설치된 CCTV  2015년 2016년 2017년  2018년 2019년 2020년  2021년  \
# 0  종로구  2,031                549    158   128   143    142    67   237     82
# 1  중 구  2,718                275    236   239   372    386   155   364    419
# 2  용산구  3,258                 88     38   295   491    147   335   473    486
# 3  성동구  4,409                190    352   278   939    457   640   483    366
# 4  광진구  3,828                309     95    42   666    460   712   191    740
#
#    2022년 2023년
# 0    225   300
# 1    137   135
# 2    500   405
# 3    233   471
# 4    273   340

# %%
CCTV_Seoul.rename(columns={CCTV_Seoul.columns[0]:'구별'}, inplace = True)
CCTV_Seoul.rename(columns={CCTV_Seoul.columns[1]:'소계'}, inplace = True)
CCTV_Seoul.rename(columns={CCTV_Seoul.columns[2]:'2015년도 이전'}, inplace = True)
CCTV_Seoul.head()
# Out:
#     구별     소계 2015년도 이전  2015년 2016년 2017년  2018년 2019년 2020년  2021년  2022년  \
# 0  종로구  2,031       549    158   128   143    142    67   237     82    225
# 1  중 구  2,718       275    236   239   372    386   155   364    419    137
# 2  용산구  3,258        88     38   295   491    147   335   473    486    500
# 3  성동구  4,409       190    352   278   939    457   640   483    366    233
# 4  광진구  3,828       309     95    42   666    460   712   191    740    273
#
#   2023년
# 0   300
# 1   135
# 2   405
# 3   471
# 4   340

# %%
pop_Seoul = pd.read_excel('01. population_in_Seoul.xls' ,header=2, usecols='B,D,G,J,N')
pop_Seoul.head()
# Out:
#   동별(2)     소계.1     소계.2    소계.3     소계.5
# 0    소계  9635445  9384739  250706  1768948
# 1   종로구   150550   139498   11052    29127
# 2    중구   131812   121602   10210    26302
# 3   용산구   223433   209849   13584    39671
# 4   성동구   284258   276964    7294    50098

# %%
pop_Seoul.rename(columns={pop_Seoul.columns[0]:'구별',
                         pop_Seoul.columns[1]:'인구수',
                         pop_Seoul.columns[2]:'한국인',
pop_Seoul.columns[3]:'외국인',
pop_Seoul.columns[4]:'고령자'}, inplace=True)
pop_Seoul.head()
# Out:
#     구별      인구수      한국인     외국인      고령자
# 0   소계  9635445  9384739  250706  1768948
# 1  종로구   150550   139498   11052    29127
# 2   중구   131812   121602   10210    26302
# 3  용산구   223433   209849   13584    39671
# 4  성동구   284258   276964    7294    50098

# %%
CCTV_Seoul.head()
# Out:
#     구별     소계 2015년도 이전  2015년 2016년 2017년  2018년 2019년 2020년  2021년  2022년  \
# 0  종로구  2,031       549    158   128   143    142    67   237     82    225
# 1  중 구  2,718       275    236   239   372    386   155   364    419    137
# 2  용산구  3,258        88     38   295   491    147   335   473    486    500
# 3  성동구  4,409       190    352   278   939    457   640   483    366    233
# 4  광진구  3,828       309     95    42   666    460   712   191    740    273
#
#   2023년
# 0   300
# 1   135
# 2   405
# 3   471
# 4   340

# %%
CCTV_Seoul.sort_values(by='소계', ascending= True).head(5)
# Out:
#      구별     소계 2015년도 이전  2015년 2016년 2017년  2018년 2019년 2020년  2021년  2022년  \
# 0   종로구  2,031       549    158   128   143    142    67   237     82    225
# 9   도봉구  2,378         3      0    68    80    152   149   156    552    557
# 1   중 구  2,718       275    236   239   372    386   155   364    419    137
# 10  노원구  3,006       156    466   310   162    208   311   382    213    161
# 19  동작구  3,024       534    124   245   270    299   312   433     28    372
#
#    2023년
# 0    300
# 9    661
# 1    135
# 10   637
# 19   407

# %%
CCTV_Seoul.sort_values(by='소계', ascending= False).head(5)
# Out:
#      구별     소계 2015년도 이전  2015년  2016년  2017년  2018년 2019년 2020년  2021년  \
# 22  강남구  7,721       672    814  1,280    981    735   787   913    505
# 20  관악구  5,772       774    447    607    675    663   889   404    549
# 21  서초구  5,395       227    552    514  1,022    422   339   419    565
# 11  은평구  5,027       524    317    493    361    579   979   386    520
# 16  구로구  5,003       406    248    340    543    531   781   652    685
#
#     2022년 2023년
# 22    588   446
# 20    135   629
# 21    878   457
# 11    481   387
# 16    339   478

# %%
CCTV_Seoul.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   구별         25 non-null     object
#  1   소계         25 non-null     object
#  2   2015년도 이전  25 non-null     int32
#  3   2015년      25 non-null     int64
#  4   2016년      25 non-null     object
#  5   2017년      25 non-null     object
#  6   2018년      25 non-null     int64
#  7   2019년      25 non-null     object
#  8   2020년      25 non-null     object
#  9   2021년      25 non-null     int64
#  10  2022년      25 non-null     int64
#  11  2023년      25 non-null     object
# dtypes: int32(1), int64(4), object(7)
# memory usage: 2.4+ KB

# %%
print(CCTV_Seoul['2015년도 이전'].dtype)
# Out:
# int32

# %%
CCTV_Seoul.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   구별         25 non-null     object
#  1   소계         25 non-null     object
#  2   2015년도 이전  25 non-null     int32
#  3   2015년      25 non-null     int64
#  4   2016년      25 non-null     object
#  5   2017년      25 non-null     object
#  6   2018년      25 non-null     int64
#  7   2019년      25 non-null     object
#  8   2020년      25 non-null     object
#  9   2021년      25 non-null     int64
#  10  2022년      25 non-null     int64
#  11  2023년      25 non-null     object
# dtypes: int32(1), int64(4), object(7)
# memory usage: 2.4+ KB

# %%
CCTV_Seoul['2023년'] = CCTV_Seoul['2023년'].str.replace('\n', '')
CCTV_Seoul['2023년'] = CCTV_Seoul['2023년'].str.replace(',', '')

# %%
CCTV_Seoul.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   구별         25 non-null     object
#  1   소계         25 non-null     object
#  2   2015년도 이전  25 non-null     int32
#  3   2015년      25 non-null     int64
#  4   2016년      25 non-null     object
#  5   2017년      25 non-null     object
#  6   2018년      25 non-null     int64
#  7   2019년      25 non-null     object
#  8   2020년      25 non-null     object
#  9   2021년      25 non-null     int64
#  10  2022년      25 non-null     int64
#  11  2023년      25 non-null     object
#  12  최근증가율      25 non-null     float64
# dtypes: float64(1), int32(1), int64(4), object(7)
# memory usage: 2.6+ KB

# %%
# '2015년도 이전' 열의 쉼표를 제거하고 정수로 변환합니다.
#CCTV_Seoul['2015년도 이전'] = CCTV_Seoul['2015년도 이전'].str.replace(',', '').astype(int)

# 다시 계산하여 최근 증가율을 구합니다.
CCTV_Seoul['최근증가율'] = ( CCTV_Seoul['2022년'] + CCTV_Seoul['2021년']) / CCTV_Seoul['2015년도 이전'] * 100

# 정렬하여 상위 5개를 출력합니다.
result = CCTV_Seoul.sort_values(by='최근증가율', ascending=False).head(5)
print(result)
# Out:
#       구별     소계  2015년도 이전  2015년 2016년 2017년  2018년 2019년 2020년  2021년  \
# 17   금천구  3,169          0     92   130   196    539   366   514    207
# 9    도봉구  2,378          3      0    68    80    152   149   156    552
# 14   양천구  4,447          4    216   418   566    827   321   352    347
# 5   동대문구  3,268          8     70   749   670    199   215   229    226
# 8    강북구  3,331         37     68   210     4    375   963   569    298
#
#     2022년                                              2023년         최근증가율
# 17    304  0       300\n1       135\n2       405\n3      ...           inf
# 9     557  0       300\n1       135\n2       405\n3      ...  3.696667e+04
# 14    386  0       300\n1       135\n2       405\n3      ...  1.832500e+04
# 5     317  0       300\n1       135\n2       405\n3      ...  6.787500e+03
# 8     797  0       300\n1       135\n2       405\n3      ...  2.959459e+03

# %%
pop_Seoul.head()
# Out:
#     구별      인구수      한국인     외국인      고령자
# 0   소계  9635445  9384739  250706  1768948
# 1  종로구   150550   139498   11052    29127
# 2   중구   131812   121602   10210    26302
# 3  용산구   223433   209849   13584    39671
# 4  성동구   284258   276964    7294    50098

# %%
pop_Seoul.drop([0],inplace =True)
pop_Seoul.head()
# Out:
#     구별     인구수     한국인    외국인    고령자
# 1  종로구  150550  139498  11052  29127
# 2   중구  131812  121602  10210  26302
# 3  용산구  223433  209849  13584  39671
# 4  성동구  284258  276964   7294  50098
# 5  광진구  350925  335105  15820  57768

# %%
pop_Seoul['구별'].unique()
# Out:
# array(['종로구', '중구', '용산구', '성동구', '광진구', '동대문구', '중랑구', '성북구', '강북구',
#        '도봉구', '노원구', '은평구', '서대문구', '마포구', '양천구', '강서구', '구로구', '금천구',
#        '영등포구', '동작구', '관악구', '서초구', '강남구', '송파구', '강동구'], dtype=object)

# %%
pop_Seoul[pop_Seoul['구별'].isnull()]
#nan 값이 없음
# Out:
# Empty DataFrame
# Columns: [구별, 인구수, 한국인, 외국인, 고령자]
# Index: []

# %%
pop_Seoul['외국인비율'] = pop_Seoul['외국인']/pop_Seoul['인구수']*100
pop_Seoul['고령자비율'] = pop_Seoul['고령자']/pop_Seoul['인구수']*100

# %%
pop_Seoul.head()
# Out:
#     구별     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 1  종로구  150550  139498  11052  29127  7.341083  19.347061
# 2   중구  131812  121602  10210  26302  7.745880  19.954177
# 3  용산구  223433  209849  13584  39671  6.079675  17.755211
# 4  성동구  284258  276964   7294  50098  2.565979  17.624130
# 5  광진구  350925  335105  15820  57768  4.508086  16.461637

# %%
pop_Seoul.sort_values(by='인구수',ascending = False).head(10)
# Out:
#      구별     인구수     한국인    외국인     고령자     외국인비율      고령자비율
# 24  송파구  659661  653736   5925  110520  0.898189  16.754060
# 16  강서구  567159  561386   5773  103825  1.017880  18.306154
# 23  강남구  559720  554280   5440   88662  0.971915  15.840420
# 11  노원구  501727  497064   4663   97596  0.929390  19.452013
# 21  관악구  497827  481958  15869   86455  3.187654  17.366475
# 12  은평구  470185  466007   4178   95209  0.888586  20.249264
# 25  강동구  465549  461367   4182   84456  0.898294  18.141162
# 15  양천구  437774  434528   3246   77423  0.741478  17.685609
# 8   성북구  436901  424881  12020   81280  2.751195  18.603757
# 17  구로구  414271  391387  22884   81360  5.523920  19.639318

# %%
pop_Seoul.sort_values(by='외국인',ascending = False).head(10)
# Out:
#       구별     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 17   구로구  414271  391387  22884  81360  5.523920  19.639318
# 19  영등포구  397942  375148  22794  68650  5.727970  17.251258
# 6   동대문구  360211  341987  18224  67880  5.059257  18.844511
# 21   관악구  497827  481958  15869  86455  3.187654  17.366475
# 5    광진구  350925  335105  15820  57768  4.508086  16.461637
# 13  서대문구  320378  305986  14392  58797  4.492194  18.352384
# 3    용산구  223433  209849  13584  39671  6.079675  17.755211
# 18   금천구  240680  227160  13520  46198  5.617417  19.194781
# 8    성북구  436901  424881  12020  81280  2.751195  18.603757
# 14   마포구  374962  363645  11317  58592  3.018173  15.626117

# %%
pop_Seoul.sort_values(by='외국인비율', ascending = False).head(5)
# Out:
#       구별     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 2     중구  131812  121602  10210  26302  7.745880  19.954177
# 1    종로구  150550  139498  11052  29127  7.341083  19.347061
# 3    용산구  223433  209849  13584  39671  6.079675  17.755211
# 19  영등포구  397942  375148  22794  68650  5.727970  17.251258
# 18   금천구  240680  227160  13520  46198  5.617417  19.194781

# %%
pop_Seoul.sort_values(by='고령자', ascending=False ).head(5)
# Out:
#      구별     인구수     한국인   외국인     고령자     외국인비율      고령자비율
# 24  송파구  659661  653736  5925  110520  0.898189  16.754060
# 16  강서구  567159  561386  5773  103825  1.017880  18.306154
# 11  노원구  501727  497064  4663   97596  0.929390  19.452013
# 12  은평구  470185  466007  4178   95209  0.888586  20.249264
# 23  강남구  559720  554280  5440   88662  0.971915  15.840420

# %%
pop_Seoul.sort_values(by='고령자비율',ascending=False).head(5)
# Out:
#      구별     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 9   강북구  291372  286400   4972  69366  1.706410  23.806680
# 10  도봉구  308864  306346   2518  71572  0.815246  23.172659
# 7   중랑구  387433  381966   5467  80250  1.411083  20.713259
# 12  은평구  470185  466007   4178  95209  0.888586  20.249264
# 2    중구  131812  121602  10210  26302  7.745880  19.954177

# %%
#인구대비 CCTV의 현황
data_result = pd.merge(CCTV_Seoul, pop_Seoul, on ='구별')
data_result.head()
# Out:
#      구별     소계  2015년도 이전  2015년 2016년 2017년  2018년 2019년 2020년  2021년  2022년  \
# 0   종로구  2,031        549    158   128   143    142    67   237     82    225
# 1   용산구  3,258         88     38   295   491    147   335   473    486    500
# 2   성동구  4,409        190    352   278   939    457   640   483    366    233
# 3   광진구  3,828        309     95    42   666    460   712   191    740    273
# 4  동대문구  3,268          8     70   749   670    199   215   229    226    317
#
#                                                2023년        최근증가율     인구수  \
# 0  0       3001       1352       4053       4714 ...    55.919854  150550
# 1  0       3001       1352       4053       4714 ...  1120.454545  223433
# 2  0       3001       1352       4053       4714 ...   315.263158  284258
# 3  0       3001       1352       4053       4714 ...   327.831715  350925
# 4  0       3001       1352       4053       4714 ...  6787.500000  360211
#
#       한국인    외국인    고령자     외국인비율      고령자비율
# ...

# %%
#del data_result['2015년도 이전']
del data_result['2016년']
del data_result['2017년']
del data_result['2018년']
del data_result['2019년']
del data_result['2020년']
del data_result['2021년']
del data_result['2022년']
del data_result['2023년']
data_result.head()
# Out:
#      구별     소계        최근증가율     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 0   종로구  2,031    55.919854  150550  139498  11052  29127  7.341083  19.347061
# 1   용산구  3,258  1120.454545  223433  209849  13584  39671  6.079675  17.755211
# 2   성동구  4,409   315.263158  284258  276964   7294  50098  2.565979  17.624130
# 3   광진구  3,828   327.831715  350925  335105  15820  57768  4.508086  16.461637
# 4  동대문구  3,268  6787.500000  360211  341987  18224  67880  5.059257  18.844511

# %%
data_result.set_index('구별', inplace =True)
data_result.head()
# Out:
#          소계        최근증가율     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 구별
# 종로구   2,031    55.919854  150550  139498  11052  29127  7.341083  19.347061
# 용산구   3,258  1120.454545  223433  209849  13584  39671  6.079675  17.755211
# 성동구   4,409   315.263158  284258  276964   7294  50098  2.565979  17.624130
# 광진구   3,828   327.831715  350925  335105  15820  57768  4.508086  16.461637
# 동대문구  3,268  6787.500000  360211  341987  18224  67880  5.059257  18.844511

# %%
data_result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 24 entries, 종로구 to 강동구
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   소계      24 non-null     object
#  1   최근증가율   24 non-null     float64
#  2   인구수     24 non-null     int64
#  3   한국인     24 non-null     int64
#  4   외국인     24 non-null     int64
#  5   고령자     24 non-null     int64
#  6   외국인비율   24 non-null     float64
#  7   고령자비율   24 non-null     float64
# dtypes: float64(3), int64(4), object(1)
# memory usage: 1.7+ KB

# %%
#어떤 자료와 CCTV수를 비교하면 좋을지를 상관계수를 통해 의미있는 자료를 뽑자
import pandas as pd
import numpy as np
data_result['소계']=data_result['소계'].str.replace(',','').astype(int)
np.corrcoef(data_result['고령자비율'],data_result['소계'])
# Out:
# array([[ 1.        , -0.41080564],
#        [-0.41080564,  1.        ]])

# %%
np.corrcoef(data_result['외국인비율'],data_result['소계'])
# Out:
# array([[ 1.        , -0.28455734],
#        [-0.28455734,  1.        ]])

# %%
np.corrcoef(data_result['인구수'],data_result['소계'])
# Out:
# array([[1.       , 0.5234565],
#        [0.5234565, 1.       ]])

# %%
data_result.sort_values(by='소계', ascending=False).head(5)
# Out:
#        소계       최근증가율     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 구별
# 강남구  7721  162.648810  559720  554280   5440  88662  0.971915  15.840420
# 관악구  5772   88.372093  497827  481958  15869  86455  3.187654  17.366475
# 서초구  5395  635.682819  412275  407840   4435  66556  1.075738  16.143593
# 은평구  5027  191.030534  470185  466007   4178  95209  0.888586  20.249264
# 구로구  5003  252.216749  414271  391387  22884  81360  5.523920  19.639318

# %%
data_result.sort_values(by='인구수', ascending=False).head(5)
# Out:
#        소계       최근증가율     인구수     한국인    외국인     고령자     외국인비율      고령자비율
# 구별
# 송파구  4031  260.986547  659661  653736   5925  110520  0.898189  16.754060
# 강서구  3546  342.244224  567159  561386   5773  103825  1.017880  18.306154
# 강남구  7721  162.648810  559720  554280   5440   88662  0.971915  15.840420
# 노원구  3006  239.743590  501727  497064   4663   97596  0.929390  19.452013
# 관악구  5772   88.372093  497827  481958  15869   86455  3.187654  17.366475

# %%
#시각화
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#matplotlib이 기본으로 가진 폰트는 한글을 지원하지 않기 때문에 폰트 변경 필요
import platform


from matplotlib import font_manager , rc
plt.rcParams['axes.unicode_minus']=False

if platform.system() =='Darwin':
    rc('font', family = 'AppleGothic')
elif platform.system()=='Windows':
    path="c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family = font_name)
else:
    print('Unknown system.. sorry~~~~')

# %%
data_result.head()
# Out:
#         소계        최근증가율     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 구별
# 종로구   2031    55.919854  150550  139498  11052  29127  7.341083  19.347061
# 용산구   3258  1120.454545  223433  209849  13584  39671  6.079675  17.755211
# 성동구   4409   315.263158  284258  276964   7294  50098  2.565979  17.624130
# 광진구   3828   327.831715  350925  335105  15820  57768  4.508086  16.461637
# 동대문구  3268  6787.500000  360211  341987  18224  67880  5.059257  18.844511

# %%
data_result['소계'].plot(kind='barh', grid = True, figsize = (10,10))
plt.show()

# %%
#정렬해서 다시 그림
data_result['소계'].sort_values().plot(kind='barh', grid=True, figsize=(10,10))
plt.show()

# %%
#인구대비 cctv 비율을 계산하여 보겟음
data_result['CCTV비율']= data_result['소계']/data_result['인구수']*100
data_result['CCTV비율'].sort_values().plot(kind='barh', grid= True, figsize=(10,10))

plt.show()

# %%
plt.figure(figsize=(6,6))
plt.scatter(data_result['인구수'], data_result['소계'], s=50)
plt.xlabel('인구수')
plt.ylabel('CCTV')
plt.grid()
plt.show()

# %%
fp1=np.polyfit(data_result['인구수'], data_result['소계'],1)
fp1
# Out:
# array([5.43677648e-03, 1.88032798e+03])

# %%
import numpy as np
f1=np.poly1d(fp1)
fx=np.linspace(100000,700000,100)

# %%
plt.figure(figsize=(10,10))
plt.scatter(data_result['인구수'], data_result['소계'],s=50)
plt.plot(fx, f1(fx), ls= 'dashed', lw=3, color='g')
plt.xlabel('인구수')
plt.ylabel('CCTV')
plt.grid()
plt.show()

# %%
fp1= np.polyfit(data_result['인구수'], data_result['소계'],1)

f1= np.poly1d(fp1)
fx= np.linspace(100000, 700000, 100)
data_result['오차'] = np.abs(data_result['소계']- f1(data_result['인구수']))

df_sort = data_result.sort_values(by='오차', ascending =False)
df_sort.head()
# Out:
#        소계       최근증가율     인구수     한국인   외국인     고령자     외국인비율      고령자비율  \
# 구별
# 강남구  7721  162.648810  559720  554280  5440   88662  0.971915  15.840420
# 노원구  3006  239.743590  501727  497064  4663   97596  0.929390  19.452013
# 송파구  4031  260.986547  659661  653736  5925  110520  0.898189  16.754060
# 강서구  3546  342.244224  567159  561386  5773  103825  1.017880  18.306154
# 서초구  5395  635.682819  412275  407840  4435   66556  1.075738  16.143593
#
#        CCTV비율           오차
# 구별
# 강남구  1.379440  2797.599484
# 노원구  0.599131  1602.105538
# 송파구  0.611071  1435.757394
# 강서구  0.625221  1417.844696
# 서초구  1.308593  1273.224992

# %%
plt.figure(figsize=(10,10))
plt.scatter(data_result['인구수'], data_result['소계'],c=data_result['오차'], s=50)
plt.plot(fx, f1(fx), ls='dashed', lw=3, color='g')

for n in range(10):
    plt.text(df_sort['인구수'][n]*1.02, df_sort['소계'][n]*0.98,
             df_sort.index[n], fontsize=15)
plt.xlabel ('인구수')
plt.ylabel('인구당비율')

plt.colorbar()
plt.grid()
plt.show()
# Out:
# C:\Users\jyuji\AppData\Local\Temp\ipykernel_23496\2644516191.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.text(df_sort['인구수'][n]*1.02, df_sort['소계'][n]*0.98,

# %%
#송파구는 인구 대비 다른 구와도 비교적 적은 수의 cctv를 가지고 있는 것을 알 수 있다
